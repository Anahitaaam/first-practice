# %% [markdown]
# <a href="https://colab.research.google.com/github/Anahitaaam/first-practice/blob/main/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
car_sales= pd.read_csv('/content/21708170-car-sales[UdemyIran.Com].csv')
car_sales
car_sales.to_csv('exported_car_sales.csv' ,index =0)
exported= pd.read_csv('/content/exported_car_sales.csv')
exported
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales['Doors'].sum()
# Out:
# 40

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales.iloc[6]
# Out:
# Make                 Honda
# Colour                Blue
# Odometer (KM)        45698
# Doors                    4
# Price            $7,500.00
# Name: 6, dtype: object

# %%
car_sales [car_sales ["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
pd.crosstab(car_sales [ 'Make'],car_sales['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(['Make']).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
import matplotlib as plt
car_sales['Odometer (KM)'].plot

# %%
car_sales['Odometer (KM)'].hist()

# %%
car_sales['Price'] = car_sales['Price'].str.replace('[\$\,\.]','').astype(int)
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 528.0+ bytes

# %%
car_sales['Make']=car_sales['Make'].str.lower()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
seat_column = pd.Series([5,5,5,5,5])
car_sales['seats']= seat_column
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    NaN
# 6   honda   Blue          45698      4   750000    NaN
# 7   honda   Blue          54738      4   700000    NaN
# 8  toyota  White          60000      4   625000    NaN
# 9  nissan  White          31600      4   970000    NaN

# %%
car_sales['seats'].fillna(5,inplace = True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    5.0
# 6   honda   Blue          45698      4   750000    5.0
# 7   honda   Blue          54738      4   700000    5.0
# 8  toyota  White          60000      4   625000    5.0
# 9  nissan  White          31600      4   970000    5.0

# %%
fuel_economy=[7.5,9.2,5.0,9.6,8.7,4.7,2.3,4.8,7.1,3.0]
car_sales['fuel per 100KM']=fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fuel per 100KM
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
# 5  toyota  Green          99213      4   450000    5.0             4.7
# 6   honda   Blue          45698      4   750000    5.0             2.3
# 7   honda   Blue          54738      4   700000    5.0             4.8
# 8  toyota  White          60000      4   625000    5.0             7.1
# 9  nissan  White          31600      4   970000    5.0             3.0

# %%
car_sales['Total fuel used']= car_sales['Odometer (KM)']/ 100* car_sales['fuel per 100KM']
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
# 5  toyota  Green          99213      4   450000    5.0             4.7
# 6   honda   Blue          45698      4   750000    5.0             2.3
# 7   honda   Blue          54738      4   700000    5.0             4.8
# 8  toyota  White          60000      4   625000    5.0             7.1
# 9  nissan  White          31600      4   970000    5.0             3.0
#
#    Total fuel used
# 0        11253.225
# 1         8086.708
# 2         1627.450
# 3         1073.184
# 4        18539.265
# 5         4663.011
# 6         1051.054
# 7         2627.424
# ...

# %%
car_sales['wheels'] =4
car_sales['passed road safety']= True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             7.5
# 1   honda    Red          87899      4   500000    5.0             9.2
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 4  nissan  White         213095      4   350000    5.0             8.7
# 5  toyota  Green          99213      4   450000    5.0             4.7
# 6   honda   Blue          45698      4   750000    5.0             2.3
# 7   honda   Blue          54738      4   700000    5.0             4.8
# 8  toyota  White          60000      4   625000    5.0             7.1
# 9  nissan  White          31600      4   970000    5.0             3.0
#
#    Total fuel used  wheels  passed road safety
# 0        11253.225       4                True
# 1         8086.708       4                True
# ...

# %%
car_sales_shuffled = car_sales.sample(frac =1)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fuel per 100KM  \
# 1   honda    Red          87899      4   500000    5.0             9.2
# 4  nissan  White         213095      4   350000    5.0             8.7
# 6   honda   Blue          45698      4   750000    5.0             2.3
# 5  toyota  Green          99213      4   450000    5.0             4.7
# 2  toyota   Blue          32549      3   700000    5.0             5.0
# 0  toyota  White         150043      4   400000    5.0             7.5
# 9  nissan  White          31600      4   970000    5.0             3.0
# 8  toyota  White          60000      4   625000    5.0             7.1
# 3     bmw  Black          11179      5  2200000    5.0             9.6
# 7   honda   Blue          54738      4   700000    5.0             4.8
#
#    Total fuel used  wheels  passed road safety
# 1         8086.708       4                True
# 4        18539.265       4                True
# ...

# %%
car_sales_shuffled.reset_index(drop =True,inplace=True)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fuel per 100KM  \
# 0   honda    Red          87899      4   500000    5.0             9.2
# 1  nissan  White         213095      4   350000    5.0             8.7
# 2   honda   Blue          45698      4   750000    5.0             2.3
# 3  toyota  Green          99213      4   450000    5.0             4.7
# 4  toyota   Blue          32549      3   700000    5.0             5.0
# 5  toyota  White         150043      4   400000    5.0             7.5
# 6  nissan  White          31600      4   970000    5.0             3.0
# 7  toyota  White          60000      4   625000    5.0             7.1
# 8     bmw  Black          11179      5  2200000    5.0             9.6
# 9   honda   Blue          54738      4   700000    5.0             4.8
#
#    Total fuel used  wheels  passed road safety
# 0         8086.708       4                True
# 1        18539.265       4                True
# ...

# %%
car_sales['Odometer (KM)']= car_sales['Odometer (KM)'].apply(lambda x:x/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fuel per 100KM  \
# 0  toyota  White   36631.591797      4   400000    5.0             7.5
# 1   honda    Red   21459.716797      4   500000    5.0             9.2
# 2  toyota   Blue    7946.533203      3   700000    5.0             5.0
# 3     bmw  Black    2729.248047      5  2200000    5.0             9.6
# 4  nissan  White   52025.146484      4   350000    5.0             8.7
# 5  toyota  Green   24221.923828      4   450000    5.0             4.7
# 6   honda   Blue   11156.738281      4   750000    5.0             2.3
# 7   honda   Blue   13363.769531      4   700000    5.0             4.8
# 8  toyota  White   14648.437500      4   625000    5.0             7.1
# 9  nissan  White    7714.843750      4   970000    5.0             3.0
#
#    Total fuel used  wheels  passed road safety  Odometer (M)
# 0        11253.225       4                True  36631.591797
# 1         8086.708       4                True  21459.716797
# ...

# %% [markdown]
# ## missing values

# %%
car_sales_missing= pd.read_csv('/content/22379919-car-sales-missing-data[UdemyIran.Com].csv')
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean(), inplace=True )
